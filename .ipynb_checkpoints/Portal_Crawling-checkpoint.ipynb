# %%
import requests
from bs4 import BeautifulSoup ##html 싹 가져와주는 애
from selenium import webdriver ##웹드라이버 돌려주는애
import pandas as pd
import time

webdriver_options = webdriver.ChromeOptions()
webdriver_options.add_argument('headless') ##창 띄우지 만 상태에서 알아서 해라
webdriver_options.add_argument('window-size=1920x1080') ## 창 사이즈 지정해줘야 렉 안 먹음
webdriver_options.add_argument("disable-gpu") ##크롬드라이버가 gpu 부스터를 쓰기 때문에 가끔렉 먹는거 방지용
webdriver_options.add_argument("lang=ko-KR") ##위에 코드 3개가 쓰면 영어로 전체를 돌려버려서 언어 한국말로 바꿔주기

driver = webdriver.Chrome('/Users/jonghyunkim/Downloads/chromedriver', options=webdriver_options) ##위에 정한 옵션으로 크롬을 실행하라

url = 'https://portal.korea.ac.kr/front/Intro.kpd'
driver.implicitly_wait(3) ## 드라이버 실행까지 시간이 좀 있으니 기다려 주는 역할
driver.get(url)
# driver.maximize_window() ## 창 전체화면 하기

##로그인 하기 
driver.find_element_by_name('id').send_keys('stanley41')
driver.find_element_by_name('pw').send_keys('crimson9841')
driver.find_element_by_xpath('//*[@id="loginsubmit"]').click()

driver.implicitly_wait(5) ## 로딩도 안됐는데 xpath 클릭하면 에러 뜨니까 기다려주는 역할
driver.find_element_by_xpath('//*[@id="header"]/div[2]/div/div/ul/li[4]/a').click() ##학적 졸업 클릭

driver.find_element_by_xpath('//*[@id="m126"]/a').click() ##성적사항 클릭
driver.find_element_by_xpath('//*[@id="sm280"]/a').click() ##전체성적 조회 클릭

time.sleep(3) ## 잠시 기다려!

driver.switch_to.frame('_component') ## iframe 안에 있어서 테이블이 있어서 탐색이 안되는 문제를 해결 --> 이 경우는 iframe 안에 이름이 _component라서 그렇게 찾아준거

soup = BeautifulSoup(driver.page_source, 'lxml') ## parsing 한거


## 이제 표들에서 데이터를 끌어와야 한다
element_table = soup.find_all(name='table')
table = pd.read_html(str(element_table)) ##이 url 을 주면 얘가 새로 접속을 하는데 그러면 로그인 정보가 없어서 내가 드라이버에서 보고 있는 페이지가 안보인다


driver.quit()

print(type(table[0]))
table[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         년도    학기       학수번호                     과목명  이수구분              교양영역  \
# 0   군복무중이수   NaN  GECE10600                    감정과삶    교양             윤리와사상
# 1     2017     1  BUSS16301               경영학입문(영강)    교양            전공관련교양
# 2     2017     1  GEKS001AN                 1학년 세미나    교양            1학년세미나
# 3     2017     1  GEST14400          컴퓨팅사고력과일상의빅데이터    교양             과학과기술
# 4     2017     1  GETE01102                  사고와표현Ⅰ    교양             사고와표현
# 5     2017     1  IFLS00302  ACADEMIC ENGLISH I(영강)    교양  ACADEMIC ENGLISH
# 6     2017     1  IFLS25208           교양일본어Ⅰ(외국어강의)    교양     전공관련교양(제2외국어)
# 7     2017     1  ECON12006                   경제원론I  전공필수               NaN
# 8     2017     2  BUSS15207               회계학원리(영강)    교양            전공관련교양
# 9     2017     2  BUSS15402                    경영통계    교양            전공관련교양
# 10    2017     2  GECT00101                   정보적사고    교양             정보적사고
# 11    2017     2  GESO07300                   인간관계론    교양             사회의이해
# 12    2017     2  GETE01302                  사고와표현Ⅱ    교양             사고와표현
# 13    2017     2  SPGE19402       Campus CEO 2.0(Ⅰ)    교양              선택교양
# 14    2017     2  BUSS21101                오퍼레이션스관리  전공필수               NaN
# 15    2017     2  ECON20307                  경제원론II  전공필수               NaN
# 16    2018     1  GEFC01600         그림을통해본일본고전문학과문화    교양             세계의문화
# 17    2018     1  HOEW12100             실크로드와동서문화교류    교양              선택교양
# 18    2018     1  IFLS25701            영상일본어(외국어강의)    교양            전공관련교양
# 19    2018     1  BUSS20503                   마케팅원론  전공필수               NaN
# 20    2018     1  BUSS20702                재무관리(영강)  전공필수               NaN
# 21    2018     1  BUSS21302               중급회계I(영강)  전공필수               NaN
# 22    2018  여름계절  BUSS20300                    경영수학  전공선택               NaN
# 23    2018     2  GELA13100                한국의젊은시인들    교양             문학과예술
# 24    2018     2  BUSS25402                 투자론(영강)  전공선택               NaN
# 25    2018     2  BUSS35200                    세무회계  전공선택               NaN
# 26    2018     2  BUSS38402                기업재무(영강)  전공선택               NaN
# 27    2018     2  BUSS21501                 경영정보시스템  전공필수               NaN
#
#         과목유형  학점   점수  등급   평점  재수강년도  재수강학기  재수강과목  삭제구분
# 0   군복무중이수과목   3  100   P  0.0    NaN    NaN    NaN   NaN
# 1        NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 2        NaN   1    0   P  0.0    NaN    NaN    NaN   NaN
# 3        NaN   3   94   A  4.0    NaN    NaN    NaN   NaN
# 4        NaN   2   79  C+  2.5    NaN    NaN    NaN   NaN
# 5        NaN   2   89  B+  3.5    NaN    NaN    NaN   NaN
# 6        NaN   3  100  A+  4.5    NaN    NaN    NaN   NaN
# 7        NaN   3   94   A  4.0    NaN    NaN    NaN   NaN
# 8        NaN   3  100  A+  4.5    NaN    NaN    NaN   NaN
# 9        NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 10       NaN   1    0   P  0.0    NaN    NaN    NaN   NaN
# 11       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 12       NaN   2   89  B+  3.5    NaN    NaN    NaN   NaN
# 13       NaN   3   94   A  4.0    NaN    NaN    NaN   NaN
# 14       NaN   3  100  A+  4.5    NaN    NaN    NaN   NaN
# 15       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 16       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 17       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 18       NaN   3  100  A+  4.5    NaN    NaN    NaN   NaN
# 19       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 20       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 21       NaN   3  100  A+  4.5    NaN    NaN    NaN   NaN
# 22       NaN   3   94   A  4.0    NaN    NaN    NaN   NaN
# 23       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 24       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN
# 25       NaN   3   94   A  4.0    NaN    NaN    NaN   NaN
# 26       NaN   3  100  A+  4.5    NaN    NaN    NaN   NaN
# 27       NaN   3   89  B+  3.5    NaN    NaN    NaN   NaN

# %%
driver.find_element_by_xpath('//*[@id="m127"]/a').click() ##졸업정보

# %%
driver.find_element_by_xpath('//*[@id="sm286"]/a').click()##졸업요구조건 조회

# %%
##요구조건 뽑아오기

# %%
driver.find_element_by_xpath('//*[@id="sm289"]/a').click()##졸업사정표 클릭

# %%
##졸업사정표 누르니까 팝업이 뜨는데 키보드로 엔터를 누를 필요가 있으나 어떻게 하는지 모르겠음 - 해결
from selenium.webdriver.common.alert import Alert ##경고창 뜨는거 제어하는 Alert 함수 불러오기
Alert(driver).accept() ##경고창에 확인버튼 눌러주는 역할

# %%
pd.read_html() ##안에 어떻게 넣어야 할까

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3m/s0ysqyzs3fb_mcgvm4wjzt3w0000gn/T/ipykernel_27691/1804977156.py in <module>
# ----> 1 help(driver)
#
# NameError: name 'driver' is not defined
