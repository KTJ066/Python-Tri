# %%
from bs4 import BeautifulSoup
import urllib.request as req

# %%
url1 = "https://www.amazon.com/SAMSUNG-Factory-Unlocked-Smartphone-Foldable/product-reviews/B097CNBDX2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
header = "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36"
url2 = req.Request(url1, headers = {"User-Agent" : header})

html = req.urlopen(url2)
doc = BeautifulSoup(html, "html.parser")

# %%
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title dir="ltr">
#    Amazon.com
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
#   <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
reviews = doc.find(id="cm_cr-review_list")
reviews

# %%
reviewer = []
title = []
review = []

# %%
n =[reviews.find_all(attrs={"data-hook":"genome-widget"})[n].text for n in range(0,10)]
reviewer.extend(n)
reviewer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3m/s0ysqyzs3fb_mcgvm4wjzt3w0000gn/T/ipykernel_4865/2346733502.py in <module>
# ----> 1 n =[reviews.find_all(attrs={"data-hook":"genome-widget"})[n].text for n in range(0,10)]
#       2 reviewer.extend(n)
#       3 reviewer
#
# /var/folders/3m/s0ysqyzs3fb_mcgvm4wjzt3w0000gn/T/ipykernel_4865/2346733502.py in <listcomp>(.0)
# ----> 1 n =[reviews.find_all(attrs={"data-hook":"genome-widget"})[n].text for n in range(0,10)]
#       2 reviewer.extend(n)
#       3 reviewer
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
t =[reviews.find_all(attrs={"data-hook":"review-title"})[n].text.strip() for n in range(0,10)]
title.extend(t)
title
# Out:
# ['My hands are on fire!',
#  'Nope heats like stove in 30 mins',
#  'YOU HAVE RECEIVED IT!',
#  'extremely beautiful oled device!!',
#  'A great phone',
#  "Fold 3 technology isn't mature, Samsung warranty is very bad.",
#  'Amazing, simply amazing.',
#  'Absolutely terrible',
#  'Cracks at the fold',
#  'Took a few months to decide']

# %%
b =[reviews.find_all(attrs={"data-hook":"review-body"})[n].text.strip() for n in range(0,10)]
review.extend(b)
review
# Out:
# ['The phone is good overall,  but I like to point out some flaws. The phone is hot! Yeah Im mean when i play games like Pubg and League, the phone runs really hot on my hands.  The battery is also on the lower side, 3 hours game play time is all i got . And by the way Amazon marked this phone non returnable which is odd because even the official website of Samsung allow people to try out the phone 21 days. MAKE NO SENSE.',
#  'Except for the foldable feature. nothing worth the money. heats like blast furnace in 30 mins. hangs in between. pictures dont load up in the gallery.',
#  "My Ultra phones are larger! Refund me! YOU'VE ALREADY RECEIVED IT! Please!",
#  'great phone !!',
#  'Though expensive but the features justify the cost.',
# ...

# %%
import pandas as pd
galaxy = {"Reviewer": reviewer, "Title": title, "Review": review}
Galaxy_review = pd.DataFrame(galaxy)
Galaxy_review
# Out:
#                 Reviewer                                              Title  \
# 0               Galen G.                              My hands are on fire!
# 1         SNEHA MIRAJKAR                   Nope heats like stove in 30 mins
# 2               Brigette                              YOU HAVE RECEIVED IT!
# 3                MM02SMR                  extremely beautiful oled device!!
# 4  Dr. Okechukwu E. Amah                                      A great phone
# 5        Patrick Asplund  Fold 3 technology isn't mature, Samsung warran...
# 6           Mark Moscoso                           Amazing, simply amazing.
# 7                Andy GA                                Absolutely terrible
# 8          Jake and John                                 Cracks at the fold
# 9          Michael Cohen                        Took a few months to decide
#
#                                               Review
# 0  The phone is good overall,  but I like to poin...
# ...

# %%
Top_GR = Galaxy_review.head()
Top_GR
# Out:
#                 Reviewer                              Title  \
# 0               Galen G.              My hands are on fire!
# 1         SNEHA MIRAJKAR   Nope heats like stove in 30 mins
# 2               Brigette              YOU HAVE RECEIVED IT!
# 3                MM02SMR  extremely beautiful oled device!!
# 4  Dr. Okechukwu E. Amah                      A great phone
#
#                                               Review
# 0  The phone is good overall,  but I like to poin...
# 1  Except for the foldable feature. nothing worth...
# 2  My Ultra phones are larger! Refund me! YOU'VE ...
# 3                                     great phone !!
# 4  Though expensive but the features justify the ...

# %%
Top_GR.to_excel("Galaxy_Fold_Amazon_Reviews.xlsx")

# %%
#Another Solution to print out the same table in the assignment notice

reviewer2 = []
title2 = []
review2 = []

n =[reviews.find_all(attrs={"data-hook":"genome-widget"})[n].text for n in range(0,5)]
reviewer2.extend(n)

t =[reviews.find_all(attrs={"data-hook":"review-title"})[n].text.strip() for n in range(0,5)]
title2.extend(t)

b =[reviews.find_all(attrs={"data-hook":"review-body"})[n].text.strip() for n in range(0,5)]
review2.extend(b)

galaxy2 = {"Reviewer": reviewer2, "Title": title2, "Review": review2}
Galaxy_review2 = pd.DataFrame(galaxy2)
Galaxy_review2

Galaxy_review2.to_excel("Another_Solution.xlsx")
# Out:
#                 Reviewer                              Title  \
# 0               Galen G.              My hands are on fire!
# 1         SNEHA MIRAJKAR   Nope heats like stove in 30 mins
# 2               Brigette              YOU HAVE RECEIVED IT!
# 3                MM02SMR  extremely beautiful oled device!!
# 4  Dr. Okechukwu E. Amah                      A great phone
#
#                                               Review
# 0  The phone is good overall,  but I like to poin...
# 1  Except for the foldable feature. nothing worth...
# 2  My Ultra phones are larger! Refund me! YOU'VE ...
# 3                                     great phone !!
# 4  Though expensive but the features justify the ...
